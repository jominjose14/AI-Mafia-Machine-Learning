# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3]
y = [3,4,1]

# %%
plt.plot(x,y)
plt.show()

# %%
categories = ['engineers','entrepreneurs','teachers','managers']
shares = [20,10,30,40]
colors=['r','g','y','b']
plt.pie(shares, labels=categories, colors=colors)
plt.show()

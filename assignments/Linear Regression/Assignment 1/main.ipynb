# %% [markdown]
# ## Smart Watch
# #### Linear regression assignment 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
xtrain = pd.read_csv('./Training Data/Linear_X_Train.csv').values
ytrain = pd.read_csv('./Training Data/Linear_Y_Train.csv').values

print(xtrain.shape, ytrain.shape)
# Out:
# (3750, 1) (3750, 1)

# %%
plt.scatter(xtrain,ytrain)
plt.show()

# %%
model = LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypredict = model.predict(xtrain)
plt.scatter(xtrain, ytrain, label='Data')
plt.plot(xtrain, ypredict, color='red', label='Prediction')
plt.legend()
plt.show()

# %%
xtest = pd.read_csv('./Testing Data/Linear_X_test.csv').values
ytest = model.predict(xtest)
print(ytest)
# Out:
# [[-147.52847525]
#  [ -66.26699842]
#  [-200.06209345]
#  ...
#  [  14.0382031 ]
#  [ -18.66616899]
#  [ -51.07594693]]

# %%
plt.scatter(xtest, ytest, label='Test Data')
plt.plot(xtrain, ypredict, color='red', label='Model line')
plt.legend()
plt.show()

# %%
time_i_spend = [[3.5]] # hours/day
my_score = model.predict(time_i_spend)
print(my_score)
# Out:
# [[285.63069978]]

# %%
plt.scatter(xtrain, ytrain, label='Data')
plt.plot(xtrain, ypredict, color='black', label='Model line')
plt.scatter(time_i_spend, my_score, color='red', label='My Score')
plt.legend()
plt.show()
